# %% [markdown]
# ---
# [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Setup Environment →](../02_Setup_Environment/01_Setup_Environment.ipynb)

# %% [markdown]
# # Introduction
# Python is a popular, versatile, and beginner-friendly programming language. It is widely used in web development, data science, automation, artificial intelligence, and more.
#
# **Key Features:**
# - Simple and easy-to-read syntax
# - Large standard library
# - Cross-platform compatibility
# - Strong community support
#
# **What you can do with Python:**
# - Automate repetitive tasks
# - Analyze and visualize data
# - Build web applications
# - Develop games
# - Work with machine learning and AI

# %% [markdown]
# ---
# [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Setup Environment →](../02_Setup_Environment/01_Setup_Environment.ipynb)
