# %% [markdown]
# ---
# [← Previous: Typecasting](../07_Typecasting/01_Typecasting.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Functions →](../10_Functions/01_Functions.ipynb)

# %% [markdown]
# # Loops

# %% [markdown]
# ---
# [← Previous: Typecasting](../07_Typecasting/01_Typecasting.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Functions →](../10_Functions/01_Functions.ipynb)
