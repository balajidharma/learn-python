# %% [markdown]
# ---
# [← Previous: Loops](../09_Loops/01_Loops.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Collections →](../11_Collections/01_Collections.ipynb)

# %% [markdown]
# # Functions

# %% [markdown]
# ---
# [← Previous: Loops](../09_Loops/01_Loops.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Collections →](../11_Collections/01_Collections.ipynb)
