# %% [markdown]
# <div align="center">
#   <a href="https://github.com/balajidharma/learn-python"><img src="https://raw.githubusercontent.com/balajidharma/learn-python/main/assets/images/logo.svg" alt="Learn Python" height="60"></a>
#   <br><br>
#   <a href="https://github.com/balajidharma/learn-python">⭐ Star on GitHub</a> &nbsp;|&nbsp; <a href="https://github.com/balajidharma/learn-python">📚 Learn Python</a>
# </div>
#
# ---
# [← Previous: Typecasting](../07_Typecasting/01_Typecasting.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: If Else →](02_If_Else.ipynb)

# %% [markdown]
# # Python Conditionals — Overview
#
# This section covers all the ways Python lets you branch and loop.
#
# | # | Topic | File |
# |---|-------|------|
# | 1 | If / Elif / Else | [02_If_Else.ipynb](02_If_Else.ipynb) |
# | 2 | Ternary Operator | [03_Ternary_Operator.ipynb](03_Ternary_Operator.ipynb) |
# | 3 | Match Statement | [04_Match.ipynb](04_Match.ipynb) |
# | 4 | While Loop | [05_While_Loop.ipynb](05_While_Loop.ipynb) |
# | 5 | For Loop | [06_For_Loop.ipynb](06_For_Loop.ipynb) |
# | 6 | Break, Continue, Pass | [07_Break_Continue_Pass.ipynb](07_Break_Continue_Pass.ipynb) |
# | 7 | Comprehensions | [08_Comprehensions.ipynb](08_Comprehensions.ipynb) |

# %% [markdown]
# ---
# [← Previous: Typecasting](../07_Typecasting/01_Typecasting.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: If Else →](02_If_Else.ipynb)
