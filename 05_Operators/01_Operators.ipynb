# %% [markdown]
# <div align="center">
#   <a href="https://github.com/balajidharma/learn-python"><img src="https://raw.githubusercontent.com/balajidharma/learn-python/main/assets/images/logo.svg" alt="Learn Python" height="60"></a>
#   <br><br>
#   <a href="https://github.com/balajidharma/learn-python">⭐ Star on GitHub</a> &nbsp;|&nbsp; <a href="https://github.com/balajidharma/learn-python">📚 Learn Python</a>
# </div>
#
# ---
# [← Previous: Data Types](../04_Variables_Data_Types/02_Data_Types.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Arithmetic Operators →](02_Arithmetic_Operators.ipynb)

# %% [markdown]
# # Python Operators
# Operators are special symbols that perform operations on variables and values.

# %%
# + operator to add together two values
print(6 + 7)
# Out:
# 13

# %% [markdown]
# ## Types of Python Operators
# Here's a list of different types of Python operators.
#
# - [Arithmetic Operators](02_Arithmetic_Operators.ipynb)
# - [Assignment Operators](03_Assignment_Operators.ipynb)
# - [Comparison Operators](04_Comparison_Operators.ipynb)
# - [Logical Operators](05_Logical_Operators.ipynb)
# - [Bitwise Operators](06_Bitwise_Operators.ipynb)
# - [Special Operators](07_Special_Operators.ipynb)

# %% [markdown]
# ---
# [← Previous: Data Types](../04_Variables_Data_Types/02_Data_Types.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Arithmetic Operators →](02_Arithmetic_Operators.ipynb)
