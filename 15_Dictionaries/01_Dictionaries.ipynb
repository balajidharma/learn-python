# %% [markdown]
# ---
# [← Previous: Sets](../14_Sets/01_Sets.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: User Input →](../17_User_Input/01_User_Input.ipynb)

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ---
# [← Previous: Sets](../14_Sets/01_Sets.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: User Input →](../17_User_Input/01_User_Input.ipynb)
