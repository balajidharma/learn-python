# %% [markdown]
# ---
# [← Previous: Strings](../06_Strings/01_Strings.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Loops →](../09_Loops/01_Loops.ipynb)

# %% [markdown]
# # Typecasting

# %% [markdown]
# ---
# [← Previous: Strings](../06_Strings/01_Strings.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Loops →](../09_Loops/01_Loops.ipynb)
