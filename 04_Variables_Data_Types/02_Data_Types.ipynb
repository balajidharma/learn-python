# %% [markdown]
# <div align="center">
#   <a href="https://github.com/balajidharma/learn-python"><img src="https://raw.githubusercontent.com/balajidharma/learn-python/refs/heads/main/assets/images/logo.svg" alt="Learn Python" height="180"></a>
#   <br><br>
#   <a href="https://github.com/balajidharma/learn-python">⭐ Star on GitHub</a> &nbsp;|&nbsp; <a href="https://github.com/balajidharma/learn-python">📚 Learn Python</a>
# </div>
#
# ---
# [← Previous: Variables](01_Variables.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Operators →](../05_Operators/01_Operators.ipynb)

# %% [markdown]
# # Python Data Types
#
# Python has several built-in data types that are used to store different kinds of values. The most common data types are:
#
# - **int**: Integer numbers
# - **float**: Decimal numbers
# - **str**: Text (string)
# - **bool**: Boolean values (True or False)
# - **NoneType**: Represents the absence of a value
#
# Below are examples of each data type.

# %%
# Integer (int)
num = 10
print(num, type(num))
# Out:
# 10 <class 'int'>

# %%
# Float (float)
pi = 3.14159
print(pi, type(pi))
# Out:
# 3.14159 <class 'float'>

# %%
# String (str)
message = "Hello, Python!"
print(message, type(message))
# Out:
# Hello, Python! <class 'str'>

# %%
# Boolean (bool)
is_active = True
print(is_active, type(is_active))
# Out:
# True <class 'bool'>

# %%
# NoneType
nothing = None
print(nothing, type(nothing))
# Out:
# None <class 'NoneType'>

# %% [markdown]
# # Collections (Will be covered in detail in the next section)
#
# Python also provides built-in collection data types to store multiple values:
#
# - **List**
# - **Tuple**
# - **Set**
# - **Dictionary**
#
# You will learn more about these in the [Collections](./../11_Collections/01_Collections.ipynb) section.

# %% [markdown]
# ---
# [← Previous: Variables](01_Variables.ipynb) &nbsp;|&nbsp; [🏠 Home](../README.md) &nbsp;|&nbsp; [Next: Operators →](../05_Operators/01_Operators.ipynb)
